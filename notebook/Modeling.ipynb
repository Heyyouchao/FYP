# %%
# =====================================
# Helper Functions for Dataset Exploration
# =====================================

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.preprocessing import StandardScaler
from sklearn.decomposition import PCA
from sklearn.manifold import TSNE
from sklearn.feature_selection import f_classif, mutual_info_classif
import umap
from pandas.plotting import parallel_coordinates

import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.decomposition import PCA
from sklearn.manifold import TSNE

import warnings
warnings.filterwarnings("ignore")
sns.set(style="whitegrid")

print("import succussefully")

# %%
# -----------------------------
# 1. Load RAW dataset
# -----------------------------
binary_df_raw = pd.read_csv("../data/merged/binary_dataset_clean.csv")
binary_df_raw.columns = binary_df_raw.columns.str.strip()

print("Original shape:", binary_df_raw.shape)

# Detect target column
target_col = [c for c in binary_df_raw.columns
              if 'marker' in c.lower() or 'target' in c.lower()][0]
print("Detected target column:", target_col)

# Encode target
binary_df_raw['target_num'] = binary_df_raw[target_col].astype('category').cat.codes
print("Target classes:", binary_df_raw[target_col].unique())
